# %%
#Hello! I used this notebook to look at all the ways gentoo and chinstrip penguins were increasing and decreasing in population through various sites.

# %%
import pandas as pd
df = pd.read_csv('penguins.csv')
df
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
df = df[(df['accuracy'] == 1.0) & (df['common_name'].isin(['chinstrap penguin', 'gentoo penguin'])) & (df['count_type'].isin(['chicks', 'adults']))]
df.to_csv('population.csv')

# %%
penguin_counts_df = df.groupby("common_name")["penguin_count"].sum()
penguin_counts_df
penguin_counts_df.to_csv('population.csv')

# %%
penguins_at_cuverville_df.to_csv('cuverville.csv')

# %%
penguins_at_pleneau_df.to_csv('pleneau.csv')

# %%
penguins_at_pleneau_df.groupby("year")["penguin_count"].sum()
# Out:
# year
# 1982      500.0
# 1996        0.0
# 1997        0.0
# 1999     1577.0
# 2000     1579.0
# 2001        1.0
# 2002        0.0
# 2003     3809.0
# 2004     2164.0
# 2005     2135.0
# 2006        0.0
# 2007     1574.0
# 2008     7229.0
# 2009     7299.0
# 2010     5158.0
# 2011     2981.0
# 2012     2795.0
# 2013     3246.0
# 2014    11062.0
# 2015    12394.0
# 2016     6904.0
# 2018     6961.0
# 2023     2642.0
# Name: penguin_count, dtype: float64

# %%
gentoo_brown_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Brown Station") ]
gentoo_per_year = gentoo_brown_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1995     26.0
# 1996      9.0
# 1997     14.0
# 2006    360.0
# 2008    631.0
# 2009    470.0
# 2010    228.0
# 2011    189.0
# 2012    498.0
# 2013    891.0
# 2014    802.0
# 2015    415.0
# 2016    894.0
# 2018    924.0
# 2019    165.0
# 2020    185.0
# 2022    104.0
# 2023    711.0
# Name: penguin_count, dtype: float64

# %%
df[df["common_name"] == "gentoo penguin"]
# Out:
#                                site_name site_id cammlr_region  \
# 28    Barrientos Island (Aitcho Islands)    AITC          48.1
# 29    Barrientos Island (Aitcho Islands)    AITC          48.1
# 30    Barrientos Island (Aitcho Islands)    AITC          48.1
# 31    Barrientos Island (Aitcho Islands)    AITC          48.1
# 32    Barrientos Island (Aitcho Islands)    AITC          48.1
# ...                                  ...     ...           ...
# 5142                       Yankee Harbor    YANK          48.1
# 5144                       Yankee Harbor    YANK          48.1
# 5145                       Yankee Harbor    YANK          48.1
# 5147                       Yankee Harbor    YANK          48.1
# 5148                       Yankee Harbor    YANK          48.1
#
#       longitude_epsg_4326  latitude_epsg_4326     common_name   day  month  \
# 28                -59.752             -62.407  gentoo penguin  13.0   12.0
# ...

# %%
# Filter for only Gentoo penguins
gentoo_locations = df[df["common_name"] == "gentoo penguin"]

# Get unique locations
unique_locations = gentoo_locations["site_name"].value_counts()

unique_locations.head(40)
# Out:
# site_name
# Neko Harbor (Andvord Bay)             69
# Jougla Point                          64
# Brown Bluff                           64
# Cape Shirreff                         53
# Brown Station                         52
# Port Lockroy                          50
# Dorian Bay/Damoy Point                49
# Ardley Island                         42
# Llano Point                           41
# Dorian Beacon                         41
# Stranger Point                        38
# Danco Island                          35
# Bryde Island East                     32
# Pleneau Island                        31
# Mikkelsen Harbor (Trinity Island)     31
# Barton Peninsula                      30
# Port Charcot                          29
# Bryde Island South                    28
# Orne Islands                          23
# Petermann Island                      22
# Cuverville Island                     21
# Georges Point (Ronge Island)          20
# ...

# %%
gentoo_charcot_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Pleneau Island") ]
gentoo_charcot_df
# Out:
#            site_name site_id cammlr_region  longitude_epsg_4326  \
# 3861  Pleneau Island    PLEN          48.1              -64.056
# 3862  Pleneau Island    PLEN          48.1              -64.056
# 3863  Pleneau Island    PLEN          48.1              -64.056
# 3864  Pleneau Island    PLEN          48.1              -64.056
# 3866  Pleneau Island    PLEN          48.1              -64.056
# 3867  Pleneau Island    PLEN          48.1              -64.056
# 3868  Pleneau Island    PLEN          48.1              -64.056
# 3870  Pleneau Island    PLEN          48.1              -64.056
# 3871  Pleneau Island    PLEN          48.1              -64.056
# 3872  Pleneau Island    PLEN          48.1              -64.056
# 3873  Pleneau Island    PLEN          48.1              -64.056
# 3874  Pleneau Island    PLEN          48.1              -64.056
# 3875  Pleneau Island    PLEN          48.1              -64.056
# 3876  Pleneau Island    PLEN          48.1              -64.056
# ...

# %%
gentoo_ardley_island_df.to_csv('penguinardley_island.csv',index=False)

# %%
gentoo_brown_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Dorian Bay/Damoy Point") ]
gentoo_brown_df
# Out:
#                    site_name site_id cammlr_region  longitude_epsg_4326  \
# 1288  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1289  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1290  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1292  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1293  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1294  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1295  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1296  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1297  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1298  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1299  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# 1300  Dorian Bay/Damoy Point    DAMO          48.1              -63.497
# ...

# %%
gentoo_brown_df.to_csv('penguindorianbay.csv',index=False)

# %%
gentoo_brown_df = df[(df["common_name"] == "gentoo penguin")]
gentoo_per_year_df = gentoo_brown_df.groupby("year")["penguin_count"].sum()
gentoo_per_year_df
# Out:
# year
# 1892        40.0
# 1903         0.0
# 1947         0.0
# 1958       400.0
# 1960      1000.0
# 1965      1018.0
# 1966        45.0
# 1970       580.0
# 1971      3300.0
# 1975       254.0
# 1977       700.0
# 1978      3345.0
# 1979     10161.0
# 1980      9631.0
# 1981      9130.0
# 1982      2486.0
# 1983      7522.0
# 1984     10669.0
# 1985     10111.0
# 1986     13240.0
# 1987     32569.0
# 1988     24186.0
# 1989      5196.0
# 1990     10246.0
# 1991      8193.0
# 1992     13373.0
# 1993     16597.0
# 1994     21267.0
# 1995     12905.0
# 1996     19477.0
# 1997     18556.0
# 1998     20519.0
# 1999     25924.0
# 2000     25580.0
# 2001     24496.0
# 2002     29480.0
# 2003     40492.0
# 2004     40920.0
# 2005     53368.0
# 2006     45904.0
# 2007     48147.0
# 2008     91607.0
# 2009    104111.0
# 2010    112538.0
# 2011    104802.0
# 2012     86605.0
# 2013    122925.0
# 2014    113954.0
# 2015    134338.0
# 2016    127750.0
# 2017     60970.0
# 2018     94899.0
# ...

# %%
gentoo_per_year_df.to_csv('totalgentoo.csv')

# %%
gentoo_neko_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Neko Harbor (Andvord Bay)") ]
gentoo_per_year = gentoo_neko_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1987      397.0
# 1996      934.0
# 1999     1489.0
# 2000     1320.0
# 2002     1072.0
# 2003     2130.0
# 2004     3239.0
# 2005     3271.0
# 2006     1726.0
# 2007     2086.0
# 2008     6882.0
# 2009     7681.0
# 2010     4264.0
# 2011     3618.0
# 2012     7041.0
# 2013     3588.0
# 2014     3955.0
# 2015    12882.0
# 2016     2630.0
# 2017     1174.0
# 2018     1889.0
# 2019     3861.0
# 2020      853.0
# 2022      603.0
# 2023     1511.0
# 2024      830.0
# Name: penguin_count, dtype: float64

# %%
gentoo_neko_df.head(20)
# Out:
#                       site_name site_id cammlr_region  longitude_epsg_4326  \
# 3088  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3089  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3090  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3091  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3092  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3093  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3094  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3095  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3096  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3097  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# 3098  Neko Harbor (Andvord Bay)    NEKO          48.1              -62.533
# ...

# %%
gentoo_brown_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Neko Harbor (Andvord Bay)") ]
gentoo_per_year = gentoo_brown_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1987      397.0
# 1996      934.0
# 1999     1489.0
# 2000     1320.0
# 2002     1072.0
# 2003     2130.0
# 2004     3239.0
# 2005     3271.0
# 2006     1726.0
# 2007     2086.0
# 2008     6882.0
# 2009     7681.0
# 2010     4264.0
# 2011     3618.0
# 2012     7041.0
# 2013     3588.0
# 2014     3955.0
# 2015    12882.0
# 2016     2630.0
# 2017     1174.0
# 2018     1889.0
# 2019     3861.0
# 2020      853.0
# 2022      603.0
# 2023     1511.0
# 2024      830.0
# Name: penguin_count, dtype: float64

# %%
gentoo_brown_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Brown (Andvord Bay)") ]

# %%
gentoo_bluff_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Brown Bluff") ]
gentoo_per_year = gentoo_bluff_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1999    1184.0
# 2000     756.0
# 2001    1340.0
# 2002     698.0
# 2003    2122.0
# 2004     988.0
# 2005    1205.0
# 2006     625.0
# 2007     682.0
# 2008    4752.0
# 2009    2528.0
# 2010     749.0
# 2011    1004.0
# 2012     598.0
# 2013     230.0
# 2014     500.0
# 2015    2140.0
# 2016    3060.0
# 2017     695.0
# 2018    1947.0
# 2019    2902.0
# 2020    1199.0
# 2022    1232.0
# 2023    1057.0
# 2024    2543.0
# Name: penguin_count, dtype: float64

# %%
gentoo_bluff_df.to_csv('brownbluff.csv')

# %%
gentoo_pleneau_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Pleneau Island") ]
gentoo_per_year = gentoo_pleneau_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1982      500.0
# 1999     1577.0
# 2000     1579.0
# 2003     3809.0
# 2004     2164.0
# 2005     2135.0
# 2007     1574.0
# 2008     7229.0
# 2009     7299.0
# 2010     5158.0
# 2011     2981.0
# 2012     2795.0
# 2013     3246.0
# 2014    11062.0
# 2015    12394.0
# 2016     6904.0
# 2018     6958.0
# 2023     2642.0
# Name: penguin_count, dtype: float64

# %%
gentoo_portchar_df = df[(df["common_name"] == "gentoo penguin") & (df["site_name"] == "Port Charcot") ]
gentoo_per_year = gentoo_portchar_df.groupby("year")["penguin_count"].sum()
gentoo_per_year
# Out:
# year
# 1983     318.0
# 2001    1200.0
# 2006    1151.0
# 2007    1233.0
# 2008    1834.0
# 2009    5657.0
# 2010    3567.0
# 2011    4172.0
# 2013    5710.0
# 2014    3138.0
# 2016    2608.0
# 2018    1484.0
# 2019    1556.0
# 2020    2371.0
# 2023    2964.0
# 2024    2367.0
# Name: penguin_count, dtype: float64

# %%
#Cleaning up chinstrap penguin data. Specifically to see the Half Moon Island population. 

chinstrap_df = df[(df["common_name"] == "chinstrap penguin")& (df["site_name"] == "Half Moon Island") & (df['accuracy'] == 1.0) & (df['count_type']=='nests')]
chinstrap_df
# Out:
#              site_name site_id cammlr_region  longitude_epsg_4326  \
# 2047  Half Moon Island    HALF          48.1              -59.918
# 2048  Half Moon Island    HALF          48.1              -59.918
# 2049  Half Moon Island    HALF          48.1              -59.918
# 2050  Half Moon Island    HALF          48.1              -59.918
# 2051  Half Moon Island    HALF          48.1              -59.918
# 2052  Half Moon Island    HALF          48.1              -59.918
# 2054  Half Moon Island    HALF          48.1              -59.918
# 2057  Half Moon Island    HALF          48.1              -59.918
# 2058  Half Moon Island    HALF          48.1              -59.918
# 2059  Half Moon Island    HALF          48.1              -59.918
# 2060  Half Moon Island    HALF          48.1              -59.918
# 2061  Half Moon Island    HALF          48.1              -59.918
# 2062  Half Moon Island    HALF          48.1              -59.918
# ...

# %%
chinstrap_df.to_csv('halfmoon.csv')
